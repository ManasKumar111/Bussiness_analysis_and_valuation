# %%
pip install yahoo_fin
# Out:
# Requirement already satisfied: yahoo_fin in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (0.8.9.1)
# Requirement already satisfied: requests in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from yahoo_fin) (2.28.1)
# Requirement already satisfied: requests-html in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: feedparser in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: pandas in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from yahoo_fin) (1.3.4)
# Requirement already satisfied: sgmllib3k in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pandas->yahoo_fin) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pandas->yahoo_fin) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests->yahoo_fin) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests->yahoo_fin) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests->yahoo_fin) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: parse in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: fake-useragent in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests-html->yahoo_fin) (1.1.1)
# Requirement already satisfied: pyquery in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: bs4 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: w3lib in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from requests-html->yahoo_fin) (2.1.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.3)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.7.0)
# Requirement already satisfied: colorama in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests-html->yahoo_fin) (0.4.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from bs4->requests-html->yahoo_fin) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.3.1)
# Requirement already satisfied: importlib-resources>=5.0 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from fake-useragent->requests-html->yahoo_fin) (5.10.1)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyquery->requests-html->yahoo_fin) (1.2.0)
# Requirement already satisfied: lxml>=2.1 in c:\users\manas\desktop\sample_project_1\env\lib\site-packages (from pyquery->requests-html->yahoo_fin) (4.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yahoo_fin.stock_info as yf

# %%
balance_sheet=[]
income_statement=[]
cfs=[]
years=[]
profitability_score=0
leverage_score=0
pe_ratio=0

# %%
 tickers=["BRIGADE.NS","PRESTIGE.NS","GODREJPROP.NS","SUNTECK.NS","PHOENIXLTD.NS","OBEROIRLTY.NS","DLF.NS","SOBHA.NS","NBCC.NS","OMAXE.NS","MAHLIFE.NS"]

# %%
def get_data(ticker):
    global balance_sheet
    global income_statement
    global cfs
    global years
    balance_sheet=yf.get_balance_sheet(ticker)
    income_statement=yf.get_income_statement(ticker)
    cfs=yf.get_cash_flow(ticker)
    years=balance_sheet.columns

# %%
def profitability():
    global profitability_score
    #Scores 1 and 2 related to net income 
    net_income=income_statement[years[0]]['netIncome']
    net_income_py=income_statement[years[1]]['netIncome']
    ni_score =1 if net_income>0 else 0
    ni_score_2 =1 if net_income>net_income_py else 0 
    
    #Score 3- Operating Cash flow 
    op_cf=cfs[years[0]]['totalCashFromOperatingActivities']
    op_cf_score=1 if op_cf >0 else 0
    
    #Score 4 
    avg_assets=(balance_sheet[years[0]]['totalAssets']+balance_sheet[years[1]]['totalAssets'])/2
    avg_assets_py=(balance_sheet[years[1]]['totalAssets']+balance_sheet[years[2]]['totalAssets'])/2
    RoA=net_income/avg_assets
    print("Return On Assets->")
    print(RoA)
    RoA_py=net_income_py/avg_assets_py
    RoA_score=1 if RoA>RoA_py else 0
    #Score 5 Accruals
    total_assets=balance_sheet[years[0]]['totalAssets']
    accruals= op_cf/total_assets -RoA
    print("Accruals->")
    print(accruals)
    ac_score =1 if accruals>0 else 0
    
    profitability_score= ni_score +ni_score_2 + op_cf_score + RoA_score +ac_score 
#     print(profitability_score)

# %%
def leverage():
    global leverage_score
    #Score 6 - long-term debt ratio
    try:
        lt_debt=balance_sheet[years[0]]['longTermDebt']
        total_assets=balance_sheet[years[0]]['totalAssets']
        debt_ratio=lt_debt/total_assets
        debt_ratio_score=1 if debt_ratio<0.4 else 0
        print("debt Ratio->")
        print(debt_ratio)
    except:
        debt_ratio_score=1
    #Score 7
    current_assets=balance_sheet[years[0]]['totalCurrentAssets']
    current_liab=balance_sheet[years[0]]['totalCurrentLiabilities']
    current_ratio=current_assets/current_liab
    print("Current Ratio->")
    print(current_ratio)
    current_ratio_score=1 if current_ratio>1 else 0
    #Score 8 dol
    op_income=income_statement[years[0]]['operatingIncome']
    op_income_py=income_statement[years[1]]['operatingIncome']
    tot_Rev=income_statement[years[0]]['totalRevenue']
    tot_Rev_py=income_statement[years[1]]['totalRevenue']
    dol=(op_income-op_income_py)/(tot_Rev-tot_Rev_py)
    print("dol->")
    print(dol)
    #Score 9 dfl
    net_income=income_statement[years[0]]['netIncome']
    net_income_py=income_statement[years[1]]['netIncome']
    ebit=income_statement[years[0]]['ebit']
    ebit_py=income_statement[years[1]]['ebit']
    dfl=(net_income-net_income_py)/(ebit-ebit_py)
    print("dfl->")
    print(dfl)
    
    
    
    leverage_score=debt_ratio_score+current_ratio_score
#     print(leverage_score)

# %%
def operating_efficiency():
    #score 10 Gross Margin
    gp=income_statement[years[0]]['grossProfit']
    gp_py=income_statement[years[1]]['grossProfit']
    tot_rev=income_statement[years[0]]['totalRevenue']
    tot_rev_py=income_statement[years[1]]['totalRevenue']
    gm=(gp/tot_rev)
    print("Gross Margin->")
    print(gm)
    #Score 11 Asset Turnover
    avg_assets=(balance_sheet[years[0]]['totalAssets']+balance_sheet[years[1]]['totalAssets'])/2
    asset_turnover=(avg_assets/tot_rev)
    print("Asset-Turnover->")
    print(asset_turnover)

# %%
def pe(ticker):
    global pe_ratio
    pe_ratio=yf.get_quote_table(ticker)['PE Ratio (TTM)']
    if pe_ratio!=pe_ratio: #Check if NaN
        pe_ratio=0
    print("PE_RAtio->")
    print(pe_ratio)

# %%
for ticker in tickers:
    try:
        get_data(ticker)
        print("---------")
        print(ticker)
        print("---------")
        profitability()
        leverage()
        operating_efficiency()
        pe(ticker)
    except:
        print(ticker +": something went wrong with this ticker")
# Out:
# ---------
# BRIGADE.NS
# ---------
# Return On Assets->
# 0.005712680535751013
# Accruals->
# 0.06237747915364471
# debt Ratio->
# 0.289298732314919
# Current Ratio->
# 1.1233639019554074
# dol->
# 0.13743194668243056
# dfl->
# 0.8955876231441654
# Gross Margin->
# 0.44753533103462073
# Asset-Turnover->
# 4.83157150574567
# PE_RAtio->
# 39.16
# ---------
# PRESTIGE.NS
# ---------
# Return On Assets->
# 0.041209406494960805
# Accruals->
# 0.02908007488238324
# debt Ratio->
# 0.13148360437654585
# Current Ratio->
# 1.2325815735941505
# dol->
# 0.34725480994838104
# dfl->
# 5.514527027027027
# Gross Margin->
# 0.47221222317865247
# Asset-Turnover->
# 4.36751702011112
# PE_RAtio->
# 13.93
# ---------
# GODREJPROP.NS
# ---------
# Return On Assets->
# 0.020698024533124065
# Accruals->
# -0.04606823139062897
# debt Ratio->
# 0.05616854157258436
# Current Ratio->
# 1.8832077905552242
# dol->
# 0.43834673006528546
# dfl->
# 1.1658093536792717
# Gross Margin->
# 0.34578164043663145
# Asset-Turnover->
# 9.329013414580684
# PE_RAtio->
# 90.77
# ---------
# SUNTECK.NS
# ---------
# Return On Assets->
# 0.005254769033949198
# Accruals->
# -0.010879779058735745
# debt Ratio->
# 0.07998430295736023
# Current Ratio->
# 2.2183266846272116
# dol->
# 0.4223939110965433
# dfl->
# 0.3952043024365313
# Gross Margin->
# 0.49585304777697475
# Asset-Turnover->
# 9.303571052686973
# PE_RAtio->
# 154.44
# ---------
# PHOENIXLTD.NS
# ---------
# Return On Assets->
# 0.018452436181637954
# Accruals->
# 0.03600331631022659
# debt Ratio->
# 0.21909742729461149
# Current Ratio->
# 1.8700692307458693
# dol->
# 0.5732413516081766
# dfl->
# 0.7106949501132738
# Gross Margin->
# 0.8826174015719456
# Asset-Turnover->
# 8.87481073053838
# PE_RAtio->
# 23.29
# ---------
# OBEROIRLTY.NS
# ---------
# Return On Assets->
# 0.07548233042352598
# Accruals->
# -0.007369641903259394
# debt Ratio->
# 0.13797834665618325
# Current Ratio->
# 3.132589884484779
# dol->
# 0.2851237833277647
# dfl->
# 1.6831450634802418
# Gross Margin->
# 0.49901442866632834
# Asset-Turnover->
# 5.149313518812233
# PE_RAtio->
# 23.46
# ---------
# DLF.NS
# ---------
# Return On Assets->
# 0.02797151656068751
# Accruals->
# 0.025964378236455057
# debt Ratio->
# 0.04170125173162135
# Current Ratio->
# 2.3155724296030287
# dol->
# 0.9403570670313338
# dfl->
# 1.427775294449674
# Gross Margin->
# 0.5198922312039075
# Asset-Turnover->
# 9.384798587564761
# PE_RAtio->
# 58.34
# ---------
# SOBHA.NS
# ---------
# Return On Assets->
# 0.010334391841557185
# Accruals->
# 0.06163638969860649
# debt Ratio->
# 0.06377756375587235
# Current Ratio->
# 1.208047740722289
# dol->
# 0.356492953415094
# dfl->
# 0.24663182949356627
# Gross Margin->
# 0.5364661681668046
# Asset-Turnover->
# 4.141588913382598
# PE_RAtio->
# 87.24
# ---------
# NBCC.NS
# ---------
# Return On Assets->
# 0.016729762538057264
# Accruals->
# -0.010787847870230453
# Current Ratio->
# 1.0474140069893025
# dol->
# 0.1110636691122962
# dfl->
# -0.017053425912593387
# Gross Margin->
# 0.06617711826772542
# Asset-Turnover->
# 1.7662341301022948
# PE_RAtio->
# 37.03
# ---------
# OMAXE.NS
# ---------
# Return On Assets->
# -0.013896063057970092
# Accruals->
# 0.07960189585710284
# debt Ratio->
# 0.04335750940584589
# Current Ratio->
# 1.1048614856380636
# dol->
# 0.5184377199155524
# dfl->
# 1.0268766119180128
# Gross Margin->
# 0.09747491097442539
# Asset-Turnover->
# 18.582437682097765
# PE_RAtio->
# 0
# ---------
# MAHLIFE.NS
# ---------
# Return On Assets->
# 0.054926480467361614
# Accruals->
# -0.07204491670545585
# debt Ratio->
# 0.01979674031904122
# Current Ratio->
# 1.889794675014216
# dol->
# 0.08357075357978112
# dfl->
# 11.909301958307012
# Gross Margin->
# 0.2049847847917031
# Asset-Turnover->
# 7.146864620219457
# PE_RAtio->
# 26.19

# %%
print(balance_sheet)
# Out:
# endDate                         2022-03-31    2021-03-31    2020-03-31  \
# Breakdown
# intangibleAssets              4.680000e+05  3.730000e+05  1.791000e+06
# capitalSurplus                1.000079e+10  1.026087e+10  1.025183e+10
# totalLiab                     1.199825e+10  9.148242e+09  7.984826e+09
# totalStockholderEquity        1.788515e+10  1.631104e+10  1.701273e+10
# minorityInterest              4.910480e+08  4.197570e+08  4.193780e+08
# otherCurrentLiab              7.219283e+09  5.065007e+09  4.119199e+09
# totalAssets                   3.037444e+10  2.587904e+10  2.541693e+10
# commonStock                   1.545173e+09  5.138320e+08  5.136140e+08
# otherCurrentAssets            2.377241e+09  1.432606e+09  1.441619e+09
# retainedEarnings              4.885787e+09  3.338138e+09  4.070176e+09
# otherLiab                     6.096200e+07  2.225110e+08  1.334230e+08
# goodWill                      6.604470e+08  6.604470e+08  6.604470e+08
# treasuryStock                 1.453402e+09  2.198202e+09  2.177110e+09
# otherAssets                   1.916607e+09  1.187893e+09  9.814780e+08
# cash                          1.984238e+09  1.150288e+09  9.247380e+08
# totalCurrentLiabilities       1.130583e+10  8.173629e+09  7.212933e+09
# deferredLongTermAssetCharges  7.890220e+08  1.776740e+08           NaN
# otherStockholderEquity        1.453402e+09  2.198202e+09  2.177110e+09
# propertyPlantEquipment        2.080140e+08  1.894940e+08  2.324620e+08
# totalCurrentAssets            2.136570e+10  1.824131e+10  1.805885e+10
# longTermInvestments           6.223206e+09  5.599522e+09  5.481907e+09
# netTangibleAssets             1.722424e+10  1.565022e+10  1.635049e+10
# shortTermInvestments          1.436330e+08  6.602900e+07  1.932500e+08
# netReceivables                2.133640e+09  1.974452e+09  3.269314e+09
# longTermDebt                  6.013150e+08  7.521020e+08  6.288530e+08
# inventory                     1.441916e+10  1.344699e+10  1.204260e+10
# accountsPayable               1.733467e+09  1.348905e+09  1.275587e+09
# shortLongTermDebt                      NaN           NaN  2.499210e+08
#
# endDate                         2019-03-31
# Breakdown
# intangibleAssets              3.218000e+06
# capitalSurplus                1.024676e+10
# totalLiab                     1.020541e+10
# totalStockholderEquity        1.929542e+10
# minorityInterest              4.351100e+08
# otherCurrentLiab              5.678848e+09
# totalAssets                   2.993594e+10
# commonStock                   5.134910e+08
# otherCurrentAssets            1.852339e+09
# retainedEarnings              6.279576e+09
# otherLiab                     2.181480e+08
# goodWill                      6.604470e+08
# treasuryStock                 2.255598e+09
# otherAssets                   7.429450e+08
# cash                          1.345714e+09
# totalCurrentLiabilities       9.661275e+09
# deferredLongTermAssetCharges           NaN
# otherStockholderEquity        2.255598e+09
# propertyPlantEquipment        1.742960e+08
# totalCurrentAssets            2.147779e+10
# longTermInvestments           6.877242e+09
# netTangibleAssets             1.863176e+10
# shortTermInvestments          1.336543e+09
# netReceivables                3.365681e+09
# longTermDebt                  3.259860e+08
# inventory                     1.345080e+10
# accountsPayable               1.880471e+09
# shortLongTermDebt             2.499250e+08

# %%
# balance_sheet=yf.get_balance_sheet(ticker)
# years=balance_sheet.columns
# print(balance_sheet)

# %%
# print(balance_sheet.columns)
# print(balance_sheet[years[0]])

# %%
data=yf.get_quote_table("BRIGADE.NS")
print(data)
# Out:
# {'1y Target Est': 599.87, '52 Week Range': '376.15 - 585.00', 'Ask': '472.50 x 0', 'Avg. Volume': 201772.0, 'Beta (5Y Monthly)': 0.64, 'Bid': '472.05 x 0', "Day's Range": '466.00 - 480.95', 'EPS (TTM)': 12.09, 'Earnings Date': 'Feb 01, 2023 - Feb 06, 2023', 'Ex-Dividend Date': 'Jul 25, 2022', 'Forward Dividend & Yield': '1.50 (0.32%)', 'Market Cap': '108.988B', 'Open': 478.8, 'PE Ratio (TTM)': 39.08, 'Previous Close': 476.45, 'Quote Price': 472.5, 'Volume': 59521.0}

# %%
stat_data=yf.get_stats("GODREJPROP.NS")
print(stat_data)
# Out:
#                            Attribute         Value
# 0                  Beta (5Y Monthly)          1.04
# 1                   52-Week Change 3       -35.02%
# 2            S&P500 52-Week Change 3       -15.27%
# 3                     52 Week High 3       2074.90
# 4                      52 Week Low 3       1129.55
# 5            50-Day Moving Average 3       1256.18
# 6           200-Day Moving Average 3       1367.00
# 7                Avg Vol (3 month) 3       630.29k
# 8                 Avg Vol (10 day) 3       584.45k
# 9               Shares Outstanding 5       278.02M
# 10      Implied Shares Outstanding 6           NaN
# 11                           Float 8        90.53M
# 12              % Held by Insiders 1        63.09%
# 13          % Held by Institutions 1        20.89%
# 14                    Shares Short 4           NaN
# 15                     Short Ratio 4           NaN
# 16                Short % of Float 4           NaN
# 17   Short % of Shares Outstanding 4           NaN
# 18     Shares Short (prior month ) 4           NaN
# 19    Forward Annual Dividend Rate 4           NaN
# 20   Forward Annual Dividend Yield 4           NaN
# 21   Trailing Annual Dividend Rate 3          0.00
# 22  Trailing Annual Dividend Yield 3         0.00%
# 23   5 Year Average Dividend Yield 4           NaN
# 24                    Payout Ratio 4         0.00%
# 25                   Dividend Date 3           NaN
# 26                Ex-Dividend Date 4  Jul 27, 2015
# 27               Last Split Factor 2           2:1
# 28                 Last Split Date 3  Nov 21, 2013
# 29                  Fiscal Year Ends  Mar 31, 2022
# 30         Most Recent Quarter (mrq)  Sep 30, 2022
# 31                     Profit Margin        19.82%
# 32            Operating Margin (ttm)         7.38%
# 33            Return on Assets (ttm)         0.52%
# 34            Return on Equity (ttm)         4.76%
# 35                     Revenue (ttm)        20.19B
# 36           Revenue Per Share (ttm)         72.65
# 37    Quarterly Revenue Growth (yoy)        27.70%
# 38                Gross Profit (ttm)         6.31B
# 39                            EBITDA         1.66B
# 40    Net Income Avi to Common (ttm)            4B
# 41                 Diluted EPS (ttm)         14.63
# 42   Quarterly Earnings Growth (yoy)        53.90%
# 43                  Total Cash (mrq)        39.77B
# 44        Total Cash Per Share (mrq)        143.27
# 45                  Total Debt (mrq)        53.82B
# 46           Total Debt/Equity (mrq)         61.26
# 47               Current Ratio (mrq)          1.59
# 48        Book Value Per Share (mrq)        316.23
# 49         Operating Cash Flow (ttm)       -12.64B
# 50      Levered Free Cash Flow (ttm)       -17.27B

# %%
stat_data_2=yf.get_stats_valuation("BRIGADE.NS")
print(stat_data_2)
# Out:
#                            0        1
# 0      Market Cap (intraday)  108.01B
# 1           Enterprise Value  138.66B
# 2               Trailing P/E    38.76
# 3                Forward P/E      NaN
# 4  PEG Ratio (5 yr expected)      NaN
# 5          Price/Sales (ttm)     3.02
# 6           Price/Book (mrq)     3.52
# 7   Enterprise Value/Revenue     3.86
# 8    Enterprise Value/EBITDA    13.91
